# %% [markdown]
# ### Tree

# %% [raw]
# a tree is defined as a finite set of one or more data items (nodes), such that there is a special node called the root node of the tree and the remaining nodes are partitioned into n >= 0 disjoint subsets, each of which is itself a tree, and they are know a subtrees

# %% [markdown]
# ![image.png](attachment:a5919717-2602-4306-a343-fa188f65831d.png)

# %% [raw]
# Degree of the tree
# - The total number of children of a node is called the degree of the node
# - The highest degree of the node among all the nodes in a tree
# - Zero degree is only possible of one leaf nodes (terminal nodes)
#
# Level Number
# - root node has level 0
# - child of root node has level 1
# - child of child of root node has level 2
# - and so on
#
# Generations
# - root node has generation 1
# - child of root node has generation 2
# - child of child of root node has generaration 3
# - and so on
#
# Ancestors
# - any predecessor nodes on the path of the root to that node are called Ancestors
#
# Descendants
# -  a node x is a  descendant of another node y  if and only if y is an ancestor of y
#
# Path
# - a sequenceof connected nodes
#
# Branch
# - An intenal node is any node of a tree that has child nodes
#
# Siblings
# - common parent node

# %% [raw]
# Binary Tree
#
# - A tree with degree 2 is called a binary tree
# - A binary tree is defined as a finite set of elements , called nodes such that
#     -- T is empty( called the Null tree or empty tree), or
#     -- T contains a distinguished node R called the root of T, and the remaining nodes of T        form an ordered pair of disjoin binary trees t1, t2
#
# - Any node in the binary tree has either 0, 1 ,or 2 child

# %% [markdown]
# ![image.png](attachment:c824a82d-6322-4f26-8413-d57a7ed99941.png)

# %% [raw]
# Complete Binary Tree
# - all levels are completely filled
# - level 0 -- 1
# - level 1 -- 2
# - level 2 -- 4
# - level 3 -- 8
# - level 4 -- 16
# - level n -- 2^n

# %% [raw]
# Almost Complete Binary Tree
# - All levels are completely filled, except possibly the last level and nodes in the last      level are all left aligned

# %% [markdown]
# ![image.png](attachment:6628efa9-4c9e-4b0f-aa31-96207ce1720c.png)

# %% [markdown]
# ![image.png](attachment:945c85d8-9b67-4b33-b1d5-fddc82cfc2ca.png)

# %% [raw]
# Strict Binary Tree
# - Each node of strict Binary tree will have either 0 or 2 children

# %% [markdown]
# ![image.png](attachment:c18b3c44-7d37-4246-bd0c-6c2144e159ab.png)

# %% [raw]
# Representation of Binary Tree
# 1. Array Representation (rarely)
# 2. Linked Representation

# %% [markdown]
# Linked List Representation

# %% [raw]
# node will have
# - left
# - item
# - right

# %% [raw]
# Root --
#
# root is a node pointer
# - when root contains null, tree is empty

# %% [markdown]
# ![image.png](attachment:a1591803-63ed-4e71-b55d-410a9d17486d.png)

# %% [markdown]
# Important Discussion

# %% [raw]
# -- How to insert an item in a BT?
# -- How to traverse a BT?

# %% [markdown]
# - How to insert an item in a BT?
