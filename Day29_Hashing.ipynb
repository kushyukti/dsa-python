# %% [markdown]
# ### Hashing

# %% [raw]
# Hashing is designed to solve the problem of needing to efficiently find or store an item in a collection
#
# if we have a list of 100000 words of english and we want to search a given word in the list, it would be ineffcient to successively compare the word with all 100000 words until we find a match

# %% [raw]
# It is a technique of mapping keys, and values, into the hash table by using hash function.
# if implemented correctly, then one can achieve O(1) time complexity in searching an item in the collection of elements.
# Efficiencyc of mapping depends on the efficiency of the hash function
#
# -- Hash Table
# It is the data structure used to store elements
#
# -- Hash Function
# It is a function to map(Hash) key-values to the memory address
#
# -- Hashing
# It is a method for storing and retrieving records from a database
#
# It lets you insert, delete and search records based on search key value
# when properly implemented these operations can be performed in constant time.
#
# this is far better than O(log n) of binary search of a sorted array

# %% [raw]
# Hashing generally takes records whose key values come from a large range and stores those records in a table with a relatively small number of slots.

# %% [raw]
# Collision
#  A collision occurs when more than one value to be hashed by a particular hash function hash to the same slot in the table or data structure (hash table) being generated by the hash function.

# %% [markdown]
# ![image.png](attachment:c1a4fc6f-c262-4c9a-8cf2-0511081e076e.png)

# %%
various hash functions:

-- simple mod function
-- division method
-- binning
-- mid square method

# %% [markdown]
# Collison Resolution
# - Open Hashing
#   \N
#  ![image.png](attachment:090e91ac-3f69-47d0-9276-1ae7b2e54d86.png)
# - closed Hashing
#  ![image.png](attachment:c5093167-1826-42f1-8e9d-c73a781ef8dc.png)
