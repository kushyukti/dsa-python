# %%
from array import *

# %%
a1 = array('b',[1,2,3,4,5])

# %%
print(a1)
# Out:
# array('b', [1, 2, 3, 4, 5])

# %% [markdown]
# ![image.png](attachment:f36743b0-bb53-43d5-8191-809bda08cd27.png)

# %%
type(a1)
# Out:
# array.array

# %%
for x in a1:
    print(x,sep='_')
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ![image.png](attachment:59f2cfae-031f-498c-ab4b-9836f529e709.png)

# %%
l1 = ['Hi',1,'a']
print(l1)
# Out:
# ['Hi', 1, 'a']

# %% [markdown]
# Numpy

# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
