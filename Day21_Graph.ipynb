# %% [markdown]
# ### Graph

# %% [raw]
# Graph is a non linear data structure. It is a collection of nodes connected by edges. It's used to represent relationships between different entities.

# %% [raw]
# Graph is composed of set of vertices (V) and set of edges (E). The graph is denoted by G(V,E).
# A set of edges (E) such that each edge e in E is identified with a unique(unordered)pair [u,v]

# %% [markdown]
# ![image.png](attachment:bfcc11e5-8291-4c62-9e44-a105d415f613.png)

# %% [raw]
# square brackets for no direction , can flow through in any direction
# parenthesis for particular direction

# %% [raw]
# Adjacent Nodes (Neighbour):
# if e = [u,v]. then u and v are called adjacent nodes

# %% [raw]
# Degree of Node:
# the degree of node u , written deg(u), is the no. of edges containing u.
#
# Isolated Node:
# deg = 0

# %% [raw]
# Path
# a path of length n from a node u to a node v is defined as a sequence of n + 1 nodes.
# P = {v0,v1,v2,...,vn)
#
# The path is said to be closed, if v0 = vn

# %% [raw]
# Simple and Complex path:
#
# The path is said to be simple if all the nodes are distinct, with the exception that v0 may equal to vn otherwise it is complex path.

# %% [markdown]
# Connected Path:
# A graph is said to be connected if there is a path betweeen anay thwo of its nodes
#
# disconned Graph:
# ![image.png](attachment:ece66c86-e369-4a6e-b2ff-aa63540a0dd2.png)

# %% [markdown]
# Tree Graph:
# a connected graph T without any cycles is called a tree graph or free tree , or simply a tree.
# This means in particular, that there is a unique simple path p between any two nodes u and v
# ![image.png](attachment:7dfc9306-10a1-4ab3-94c8-52c8abcea89f.png)

# %% [raw]
# Labelled graph:
# a graph is to be labelled if ifs edges are assigned data.

# %% [raw]
# Weighted Graph:
# A graph g is said to be weighted if each edge e in G is assigned a non-negative numerical value W(e) called the weight

# %% [markdown]
# Multiple Edges
# distinct edges e and e' are called multiple edges if they connect the same end points, that is , if e = [e,v] and e'=[u,v]
# ![image.png](attachment:eaaa1986-c064-482e-a1a5-bd4e3e3e6f31.png)

# %% [raw]
# Loop
# an edge is called loop if it has identical end points.
# e = [u,u]

# %% [raw]
# Multi graph:
# it is a graph consisting of multiple edges and loops

# %% [raw]
# directed graph:
# a directed graph G also called digraph is same as multigraph except that each edge e is assigned a direction
# e =(u,v)

# %% [raw]
# Complete Graph:
# A simple graph in which there exists an edge between every pair of vertices is called a complete graph
# it is also known as a universal graph or clique

# %% [markdown]
# ![image.png](attachment:431e141e-5452-47ee-941e-246cbf50627b.png)

# %% [raw]
# Representation of Graph
# - adjancency matrix Representation
# - list representation

# %% [raw]
# Adjacency Matrix Representation
# Suppose G is a simple graph with m nodes, and suppose the nodes of G have been ordered and are called v1,c2,v3,v4....vm. Then the adjaceny matrix A = (aij) of the graph G is the mxm matrix defined as follows:
#
# aij = {   1 , if vi is adjacent to vj  # edge hai
#           0 , otherwise

# %% [markdown]
# ![image.png](attachment:27a9b161-26da-4c3d-bb85-d4c44e5b88af.png)
#
# ![image.png](attachment:afb13cb7-cff5-4ec0-b088-45f578aa4c36.png)

# %% [raw]
# Adjajency List Representation
#
# The adjacency list stores information about only those edges that exists
#
# The adjacency list contains a directory(dict) containing adjacency list for each vertex.
